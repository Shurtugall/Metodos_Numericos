# %% [markdown]
# # Trabalho T1 - Erros em Aproximações numéricas
#
# ### MTM 224 - Métodos Numéricos Computacionais
# ### Eng. Química(305) - Turma 14
#
# *Nome*: Gabriel Righi
#
# *Matrícula*: 201612819

# %% [markdown]
# ## Questão 1
# Pesquise e responda: O que é o *Épsilon da Máquina*? Apresente um programa em
# python para obter o épsilon do computador que você usa. Qual o valor obtido com
# seu programa?

# %% [markdown]
# ###### Resposta:
# Épsilon da máquina é o menor número que somado a 1 produza resultado diferente de 1. Devido a limitação de memória que podemos representar com a quantidade de bits disponíveis em um _Float_ , existe um número tão pequeno que causa um _Erro_ de arredondamento, de forma que é representado pela letra grega "ε".

# %%
'''
Definição da função "main", a qual utiliza divisões por 2 consecutivas até encontrar
o menor número representável que satisfaça a condição do "While" em que o número somado
com 1, seja maior que 1
'''

def main():
    eps = 1;
    while(eps+1) > 1:
        eps = eps/2
    
    eps = eps*2
    print(eps)
    
#Utilizado para chamar a função main    
main()
# Out:
# 2.220446049250313e-16

# %% [markdown]
# ---
# ## Questão 2
# Use um progama em Python para realizar a soma $ S1 = 1000 + \sum_{n = 0}^{10000} 0.1$ e a soma $ S2 =\sum_{n = 0}^{10000} 0.1 + 1000$. Compare os resultados e comente.

# %%
'''
Utiliza de laços de repetição para encontrar os valores das somas S1 e S2.
A grande diferença entre S1 e S2 se dá pelo fato que em S1, o valor de x é
calculado em suas iterações e ao final é somado com 1000. Já em S2, o valor de
x é calculado, onde a cada iteração o resultado já é somado com 1000
'''

#Para S1:
def main():
    x = 0
    for n in range(10000):
        x = x + 0.1

    print('O resultado de S1 é:', 1000+x)
    
#Para S2:
    x = 1000
    for i in range(10000):
        x = x + 0.1
        
    print("O resultado de S2 é:", x)

main()
# Out:
# O resultado de S1 é: 2000.0000000001587
# O resultado de S2 é: 1999.9999999991178

# %% [markdown]
# ###### Resposta:
# A diferença de valores se dá pelo fato que o computador não consegue representar certos números de forma exata, ocorrem diferenças devido aos bits utilizados ao somar números muito pequenos com números muito grandes, o que cria essa discrepância entre os valores. Enquanto S1 soma 1000 com o valor de $x$ que foi definido pela soma consecutiva no laço _for_ , o valor se faz diferente em S2, onde soma-se 0.1 a um número muito grande, no caso 1000.

# %% [markdown]
# ---
# ## Questão 3
# Considere as expressões:
# $\frac{e^{\frac{1}{x}}}{1 + e^{\frac{1}{x}}}$  e  $\frac{1}{e^{\frac{1}{x}} + 1}$. Verique que,
# para $x$ > 0, são funções idênticas, então, use um programa em Python para testar o valor de cada uma para alguns valores
# de $x$ entre 0.1 e 0.001. Qual. dessas expressões é mais adequada quando x é um número pequeno? Explique.

# %%
'''
Programa utiliza funções da biblioteca math.
O programa inicia com o valor de x = 0.001 e com um laço "For", incrementa o valor de x em 0.001.
Ocorre uma verificação se não ocorreu nenhum erro de overflow, utilizando a função "try,except".
Ao final imprime o valor da diferença entre os dois valores obtidos
'''
import math

def main():
    
    x = 0.001
    for i in range(100):
        #Verifica se ocorreu overflow
        try:
            result1 = math.exp(1/x) / (1 + math.exp(1/x))
            print("Resultado da 1ª equação com x=", x, ":", result1)
        except OverflowError:
            print("Resultado da 1ª equação com x=", x, ": Não é possível representar(Overflow)")
        
        #Verifica se ocorreu overflow
        try:
            result2 = 1 / (math.exp(1/x) + 1)
            print("Resultado da 2ª equação com x=", x, ":", result2, "\n")
        except OverflowError:
            print("Resultado da 2ª equação com x=", x, ": Não é possível representar(Overflow)\n ")
            
        x = x + 0.001
        
    diff = result1 - result2    
    print("Fim do laço de repetição!\nResultado da diferença entre os dois valores: ", diff)

main()
# Out:
# Resultado da 1ª equação com x= 0.001 : Não é possível representar(Overflow)
# Resultado da 2ª equação com x= 0.001 : Não é possível representar(Overflow)
#
# Resultado da 1ª equação com x= 0.002 : 1.0
# Resultado da 2ª equação com x= 0.002 : 7.124576406741285e-218
#
# Resultado da 1ª equação com x= 0.003 : 1.0
# Resultado da 2ª equação com x= 0.003 : 1.718591656056264e-145
#
# Resultado da 1ª equação com x= 0.004 : 1.0
# Resultado da 2ª equação com x= 0.004 : 2.6691902155412764e-109
#
# Resultado da 1ª equação com x= 0.005 : 1.0
# Resultado da 2ª equação com x= 0.005 : 1.3838965267367376e-87
#
# Resultado da 1ª equação com x= 0.006 : 1.0
# Resultado da 2ª equação com x= 0.006 : 4.145590013564129e-73
#
# Resultado da 1ª equação com x= 0.007 : 1.0
# Resultado da 2ª equação com x= 0.007 : 9.07676636045989e-63
#
# Resultado da 1ª equação com x= 0.008 : 1.0
# Resultado da 2ª equação com x= 0.008 : 5.166420632837861e-55
#
# Resultado da 1ª equação com x= 0.009000000000000001 : 1.0
# ...

# %% [markdown]
# ###### Resposta:
# Como é possível verificar, quando $x$ é um número pequeno, a precisão da segunda equação é muito superior, visto que na primeira equação, o sistema reconhece o valor apenas como 1.0. O mais provável de se afirmar é que a primeira equação trabalha com a soma números tão pequenos com números grandes de modo que o computador não reconhece e acaba "arredondando", de forma que o valor que deveria variar em 1.0 não é representado.

# %% [markdown]
# ---
# ## Questão 4
# A fórmula de Leibniz para o número $\pi$ é dada pela série infinita $\frac{\pi}{4} = \sum_{n = 0}^{\infty} \frac{(-1)^{n}}{2n+1}$. Apresente um programa em Python para obter uma aproximações para $\pi$ usando
# 50 termos da série. Calcule os erros absoluto e relativo.

# %%
"""
Programa define o valor de pi inicialmente como 0. Utiliza a fórmula de Leibniz para calcular
o valor de pi de acordo com as iterações. Vale destacar que na fórmula dada no trabalho, o valor
de pi é dividido por 4. Logo, apenas foi passado o valor que divide, multiplicando na fórmula ao lado
Ao final do cálculo da variável, é calculado o erro absoluto e o erro relativo
"""
import math

def main():
    
    pi = 0
    #Cálculo da variável pi
    for n in range(50):
        pi = pi + ((4.0*((-1)**n))/(2*n + 1))
        print(n+1,"º termo da serie: ", pi)
    
    #Cálculo do erro absoluto
    erro_absoluto = math.pi - pi
    print("\nErro absoluto: ", math.fabs(erro_absoluto))
    
    #Cálculo do erro relativo
    erro_relativo = erro_absoluto/(math.fabs(math.pi))
    print("Erro relativo: ", erro_relativo)
    
main()
# Out:
# 1 º termo da serie:  4.0
# 2 º termo da serie:  2.666666666666667
# 3 º termo da serie:  3.466666666666667
# 4 º termo da serie:  2.8952380952380956
# 5 º termo da serie:  3.3396825396825403
# 6 º termo da serie:  2.9760461760461765
# 7 º termo da serie:  3.2837384837384844
# 8 º termo da serie:  3.017071817071818
# 9 º termo da serie:  3.2523659347188767
# 10 º termo da serie:  3.0418396189294032
# 11 º termo da serie:  3.232315809405594
# 12 º termo da serie:  3.058402765927333
# 13 º termo da serie:  3.2184027659273333
# 14 º termo da serie:  3.0702546177791854
# 15 º termo da serie:  3.208185652261944
# 16 º termo da serie:  3.079153394197428
# 17 º termo da serie:  3.200365515409549
# 18 º termo da serie:  3.0860798011238346
# 19 º termo da serie:  3.1941879092319425
# 20 º termo da serie:  3.09162380666784
# 21 º termo da serie:  3.189184782277596
# 22 º termo da serie:  3.0961615264636424
# 23 º termo da serie:  3.1850504153525314
# 24 º termo da serie:  3.099944032373808
# ...

# %% [markdown]
# ## Questão 5
# O método "divida e faça a média", um método antigo para aproximar a raiz quadrada
# de qualquer número positivo $a$, pode ser formulado por $x_{i+1} = \frac{x_{i} + \frac{a}{x_{i}}}{2}$.
# Faça um programa para calcular $\sqrt7$ com erro relativo inferior a ${10}^{-5}$.

# %%
'''
Programa que utiliza a equação dada para calcular o valor aproximado da raiz de 7. Faz 10 iterações
e ao fim do do laço, faz um calculo de erro absoluto usando a biblioteca math para verificar se o valor
possui um erro relativo inferior a 10^-5
'''

import math

def main():
    a = 7
    x_ant = 0.1
    for i in range(10):
        x = (x_ant + a/x_ant)/2
        x_ant = x
        print("X", i+1, ":", x)
    
    print("\nValor exato da raiz de 7: ", math.sqrt(7))
    
    #Cálculo do erro absoluto
    erro_absoluto = math.sqrt(7.0) - x
    
    print("Erro absoluto: ", math.fabs(erro_absoluto))    
    
    
main()
# Out:
# X 1 : 35.05
# X 2 : 17.624857346647644
# X 3 : 9.011011840901388
# X 4 : 4.89391957052641
# X 5 : 3.1621329607846667
# X 6 : 2.687914308553074
# X 7 : 2.6460819983844126
# X 8 : 2.645751331727991
# X 9 : 2.6457513110645907
# X 10 : 2.6457513110645907
#
# Valor exato da raiz de 7:  2.6457513110645907
# Erro absoluto:  0.0

# %% [markdown]
# **OBS**: O valor do erro absoluto como podemos ver, de fato é inferior a ${10}^{-5}$, porém por ser um número pequeno, o computador reconheceu apenas como 0 absoluto, mas se compararmos manualmente, é possível ver a distinção de valores.
